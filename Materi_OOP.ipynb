# %% [markdown]
# <a href="https://colab.research.google.com/github/ell418/kka.-materi-OOP.py/blob/main/Materi_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Hero:
    # Constructor: Dijalankan saat Hero baru dibuat
    def __init__(self, name, hp, attack_power):
        self.name = name
        self.hp = hp
        self.attack_power = attack_power

    # Method untuk menampilkan info hero
    def info(self):
        print(f"Hero: {self.name} | HP: {self.hp} | Power: {self.attack_power}")


# -- Main Program --

# Membuat Object (Instansiasi)
hero1 = Hero("Layla", 100, 15)
hero2 = Hero("Zilong", 120, 20)

# Mengubah HP hero1
hero1.hp = 500

# Menampilkan HP hero1
print(hero1.hp)

# Memanggil Method
hero1.info()
hero2.info()
# Out:
# 500
# Hero: Layla | HP: 500 | Power: 15
# Hero: Zilong | HP: 120 | Power: 20

# %%
class Hero:
    def __init__(self, name, hp, attack_power):
        self.name = name
        self.hp = hp
        self.attack_power = attack_power

    def info(self):
        print(f"Hero: {self.name} | HP: {self.hp} | Power: {self.attack_power}")

    # Method menyerang
    def serang(self, lawan):
        print(f"{self.name} menyerang {lawan.name}!")
        lawan.diserang(self.attack_power)

    # Method diserang
    def diserang(self, damage):
        self.hp -= damage
        print(f"{self.name} terkena damage {damage}. Sisa HP: {self.hp}")


# Membuat object
hero1 = Hero("Layla", 100, 15)
hero2 = Hero("Zilong", 120, 20)

print("\n--- Pertarungan Dimulai ---")

hero1.serang(hero2)
hero2.serang(hero1)
# Out:
# --- Pertarungan Dimulai ---
# Layla menyerang Zilong!
# Zilong terkena damage 15. Sisa HP: 105
# Zilong menyerang Layla!
# Layla terkena damage 20. Sisa HP: 80

# %%
class Hero:
    def __init__(self, name, hp, attack_power):
        self.name = name
        self.hp = hp
        self.attack_power = attack_power

    def info(self):
        print(f"Hero: {self.name} | HP: {self.hp} | Power: {self.attack_power}")

    def serang(self, lawan):
        print(f"{self.name} menyerang {lawan.name}!")
        lawan.diserang(self.attack_power)

    def diserang(self, damage):
        self.hp -= damage
        print(f"{self.name} terkena damage {damage}. Sisa HP: {self.hp}")


class Mage(Hero):
    def __init__(self, name, hp, attack_power, mana):
        super().__init__(name, hp, attack_power)
        self.mana = mana

    def info(self):
        print(f"{self.name} [Mage] | HP: {self.hp} | Mana: {self.mana}")

    def skill_fireball(self, lawan):
        if self.mana >= 20:
            print(f"{self.name} menggunakan Fireball ke {lawan.name}!")
            self.mana -= 20
            lawan.diserang(self.attack_power * 2)
        else:
            print(f"{self.name} gagal skill! Mana tidak cukup.")


# -- Main Program --

print("\n--- Update Class Hero ---")

eudora = Mage("Eudora", 80, 30, 100)
balmond = Hero("Balmond", 200, 10)

eudora.info()
eudora.serang(balmond)
eudora.skill_fireball(balmond)
# Out:
# --- Update Class Hero ---
# Eudora [Mage] | HP: 80 | Mana: 100
# Eudora menyerang Balmond!
# Balmond terkena damage 30. Sisa HP: 170
# Eudora menggunakan Fireball ke Balmond!
# Balmond terkena damage 60. Sisa HP: 110

# %%
class Hero:
    def __init__(self, nama, hp_awal):
        self.nama = nama
        self.__hp = hp_awal

    def get_hp(self):
        return self.__hp

    def set_hp(self, nilai_baru):
        if nilai_baru < 0:
            self.__hp = 0
        elif nilai_baru > 1000:
            print("Cheat terdeteksi! HP dimaksimalkan ke 1000 saja.")
            self.__hp = 1000
        else:
            self.__hp = nilai_baru

    def diserang(self, damage):
        sisa_hp = self.get_hp() - damage
        self.set_hp(sisa_hp)
        print(f"{self.nama} terkena damage {damage}. Sisa HP: {self.get_hp()}")


hero1 = Hero("Layla", 100)

hero1.set_hp(-50)
print(hero1.get_hp())

print(f"Mencoba akses paksa: {hero1._Hero__hp}")
# Out:
# 0
# Mencoba akses paksa: 0

# %%
from abc import ABC, abstractmethod


class GameUnit(ABC):
    @abstractmethod
    def serang(self, target):
        pass

    @abstractmethod
    def info(self):
        pass


class Hero(GameUnit):
    def __init__(self, nama):
        self.nama = nama

    def serang(self, target):
        print(f"Hero {self.nama} menebas {target}!")

    def info(self):
        print(f"Saya adalah Hero: {self.nama}")


class Monster(GameUnit):
    def __init__(self, jenis):
        self.jenis = jenis

    def serang(self, target):
        print(f"Monster {self.jenis} menggigit {target}!")

    def info(self):
        print(f"Saya adalah Monster: {self.jenis}")


# Mencoba membuat objek dari Abstract Class
unit = GameUnit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_756/830649855.py in <cell line: 0>()
#      35
#      36 # Mencoba membuat objek dari Abstract Class
# ---> 37 unit = GameUnit()
#
# TypeError: Can't instantiate abstract class GameUnit without an implementation for abstract methods 'info', 'serang'

# %%
from abc import ABC, abstractmethod


# ==============================
# ABSTRACTION
# ==============================
class KamarHotel(ABC):

    def __init__(self, nama_kamar, stok, harga_dasar):
        self.nama_kamar = nama_kamar
        self.__stok = stok
        self.__harga_dasar = harga_dasar

    # Getter stok
    def get_stok(self):
        return self.__stok

    # Getter harga dasar
    def get_harga_dasar(self):
        return self.__harga_dasar

    # Method untuk menambah stok
    def tambah_stok(self, jumlah):
        if jumlah < 0:
            print(
                f"Gagal update stok {self.nama_kamar}! "
                f"Stok tidak boleh negatif ({jumlah})."
            )
        else:
            self.__stok += jumlah
            print(
                f"Berhasil menambahkan stok {self.nama_kamar}: "
                f"{self.__stok} unit."
            )

    @abstractmethod
    def tampilkan_detail(self):
        pass

    @abstractmethod
    def hitung_harga_total(self, jumlah_malam):
        pass


# ==============================
# INHERITANCE + POLYMORPHISM
# ==============================
class KamarDeluxe(KamarHotel):

    def __init__(self, nama_kamar, stok, harga_dasar, fasilitas):
        super().__init__(nama_kamar, stok, harga_dasar)
        self.fasilitas = fasilitas

    def tampilkan_detail(self):
        print(
            f"[DELUXE] {self.nama_kamar} | "
            f"Fasilitas: {self.fasilitas}"
        )

    def hitung_harga_total(self, jumlah_malam):
        harga_dasar = self.get_harga_dasar()
        pajak = harga_dasar * 0.10
        subtotal = (harga_dasar + pajak) * jumlah_malam

        print(
            f"Harga Dasar/Malam: Rp {harga_dasar:,.0f} | "
            f"Pajak(10%): Rp {pajak:,.0f}"
        )
        print(
            f"Menginap: {jumlah_malam} malam | "
            f"Subtotal: Rp {subtotal:,.0f}"
        )

        return subtotal


class KamarStandard(KamarHotel):

    def __init__(self, nama_kamar, stok, harga_dasar, kapasitas):
        super().__init__(nama_kamar, stok, harga_dasar)
        self.kapasitas = kapasitas

    def tampilkan_detail(self):
        print(
            f"[STANDARD] {self.nama_kamar} | "
            f"Kapasitas: {self.kapasitas}"
        )

    def hitung_harga_total(self, jumlah_malam):
        harga_dasar = self.get_harga_dasar()
        pajak = harga_dasar * 0.05
        subtotal = (harga_dasar + pajak) * jumlah_malam

        print(
            f"Harga Dasar/Malam: Rp {harga_dasar:,.0f} | "
            f"Pajak(5%): Rp {pajak:,.0f}"
        )
        print(
            f"Menginap: {jumlah_malam} malam | "
            f"Subtotal: Rp {subtotal:,.0f}"
        )

        return subtotal


# ==============================
# FITUR PEMESANAN
# ==============================
def proses_transaksi(daftar_pesanan):
    total_tagihan = 0

    print("\n--- STRUK PEMESANAN ---")

    for nomor, pesanan in enumerate(daftar_pesanan, start=1):
        kamar = pesanan["kamar"]
        jumlah_malam = pesanan["malam"]

        print(f"{nomor}. ", end="")
        kamar.tampilkan_detail()

        subtotal = kamar.hitung_harga_total(jumlah_malam)

        total_tagihan += subtotal
        print()

    print("----------------------------------------")
    print(f"TOTAL TAGIHAN: Rp {total_tagihan:,.0f}")
    print("----------------------------------------")


# ==============================
# PROGRAM UTAMA
# ==============================

print("--- SETUP DATA KAMAR ---")

# Admin membuat kamar
deluxe = KamarDeluxe(
    "Kamar Deluxe Sea View",
    0,
    1_500_000,
    "Private Pool"
)

standard = KamarStandard(
    "Kamar Standard Superior",
    0,
    500_000,
    "2 Orang"
)

# Menambahkan stok
deluxe.tambah_stok(10)

# Mencoba memasukkan stok negatif
standard.tambah_stok(-5)

# Menambahkan stok yang benar
standard.tambah_stok(20)


# Tamu melakukan pemesanan
daftar_pesanan = [
    {
        "kamar": deluxe,
        "malam": 2
    },
    {
        "kamar": standard,
        "malam": 1
    }
]

# Proses transaksi
proses_transaksi(daftar_pesanan)
# Out:
# --- SETUP DATA KAMAR ---
# Berhasil menambahkan stok Kamar Deluxe Sea View: 10 unit.
# Gagal update stok Kamar Standard Superior! Stok tidak boleh negatif (-5).
# Berhasil menambahkan stok Kamar Standard Superior: 20 unit.
#
# --- STRUK PEMESANAN ---
# 1. [DELUXE] Kamar Deluxe Sea View | Fasilitas: Private Pool
# Harga Dasar/Malam: Rp 1,500,000 | Pajak(10%): Rp 150,000
# Menginap: 2 malam | Subtotal: Rp 3,300,000
#
# 2. [STANDARD] Kamar Standard Superior | Kapasitas: 2 Orang
# Harga Dasar/Malam: Rp 500,000 | Pajak(5%): Rp 25,000
# Menginap: 1 malam | Subtotal: Rp 525,000
#
# ----------------------------------------
# TOTAL TAGIHAN: Rp 3,825,000
# ----------------------------------------
